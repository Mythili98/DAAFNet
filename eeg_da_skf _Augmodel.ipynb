# %%
import torch.nn as nn
import torch
import torch.backends.cudnn as cudnn
import torch.optim as optim
import numpy as np
import torch.nn.functional as F
import scipy
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import StratifiedKFold as skf

# %%
import os
import torch.backends.cudnn as cudnn
import torch.utils.data


def test(dataset_loader,epoch,model,name):
    cuda = True
    cudnn.benchmark = True
    image_size = 32
    alpha = 0

    dataloader = dataset_loader

    """ training """

    my_net = model
    my_net = my_net.eval()

    if cuda:
        my_net = my_net.cuda()

    len_dataloader = len(dataloader)
    data_target_iter = iter(dataloader)

    i = 0
    n_total = 0
    n_correct = 0

    while i < len_dataloader:

        # test model using target data
        data_target = next(data_target_iter)
        test_img,test_wave, test_label = data_target

        batch_size = len(test_label)

        if cuda:
            test_img = test_img.cuda()
            test_wave = test_wave.cuda()
            test_label = test_label.cuda()

        class_output, _ = my_net(input_data=test_img.float(), input_wave = test_wave.float(), alpha=alpha)
        _,pred = torch.max(class_output, dim=1)
        _,gt = torch.max(test_label,dim=1)
        n_correct += (pred == gt).sum().item()
        n_total += batch_size

        i += 1

    accu = 100*n_correct/ n_total
    print(f'Epoch {epoch} for {name} dataset is {accu}')
    return accu

# %%
import torch.nn as nn
from torch.autograd import Function


class ReverseLayerF(Function):

    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None

class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size):
        super(ResidualBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_channels)
        self.activation1 = nn.ReLU()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size, stride= 1, padding= 2)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.activation2 = nn.ReLU()
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size, stride= 1, padding= 2)
    
    def forward(self,x):
        residual  = torch.clone(x)
        x = self.bn1(x)
        x = self.activation1(x)
        x = self.conv1(x)
        x = self.conv2(self.activation2(self.bn2(x)))
        residual = residual.unsqueeze(0)
        residual = nn.functional.interpolate(residual, size = [x.shape[1], x.shape[2], x.shape[3]])
        residual = residual.squeeze(0)
        x += residual
        return x
    

class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 384
        
        # Layer 1
        self.conv1 = nn.Conv2d(1, 16, (1, 32), padding = 0)
        self.batchnorm1 = nn.BatchNorm2d(16, False)
        
        # Layer 2
        self.padding1 = nn.ZeroPad2d((16, 17, 0, 1))
        self.conv2 = nn.Conv2d(1, 4, (2, 32))
        self.batchnorm2 = nn.BatchNorm2d(4, False)
        self.pooling2 = nn.MaxPool2d(2, 4)
        
        # Layer 3
        self.padding2 = nn.ZeroPad2d((2, 1, 4, 3))
        self.conv3 = nn.Conv2d(4, 4, (8, 4))
        self.batchnorm3 = nn.BatchNorm2d(4, False)
        self.pooling3 = nn.MaxPool2d((2, 4))

    def forward(self, x):
        # Layer 1
        x = F.elu(self.conv1(x))
        x = self.batchnorm1(x)
        x = F.dropout(x, 0.25)
        x = x.permute(0, 3, 1, 2)

        # Layer 2
        x = self.padding1(x)
        x = F.elu(self.conv2(x))
        x = self.batchnorm2(x)
        x = F.dropout(x, 0.25)
        x = self.pooling2(x)
        
        # Layer 3
        x = self.padding2(x)
        x = F.elu(self.conv3(x))
        x = self.batchnorm3(x)
        x = F.dropout(x, 0.25)
        x = self.pooling3(x)
        # FC Layer
        x = x.reshape(-1, 4*2*24)
        return x
    
    
class CNNModel(nn.Module):

    def __init__(self):
        super(CNNModel, self).__init__()
        self.feature_image = nn.Sequential()
        self.feature_image.add_module('f_conv1', nn.Conv2d(in_channels = 5, out_channels = 32, kernel_size= 3, stride= 1, padding= 2))
        self.feature_image.add_module('f_resblock1', ResidualBlock(32,32,5))
        self.feature_image.add_module('f_resblock2', ResidualBlock(32,64,5))
        self.feature_image.add_module('f_resblock3', ResidualBlock(64,128,5))
        self.feature_image.add_module('f_adaptiveavgpool', nn.AdaptiveAvgPool2d((15,15)))

        self.feature_wave = nn.Sequential()
        self.feature_wave.add_module('f_EEGNet',EEGNet())

        self.class_classifier = nn.Sequential()
        self.class_classifier.add_module('c_fc1', nn.Linear(15 * 15 * 128 + 4*2*24, 1024))
        self.class_classifier.add_module('c_bn1', nn.BatchNorm1d(1024))
        self.class_classifier.add_module('c_relu1', nn.ReLU(True))
        self.class_classifier.add_module('c_drop1', nn.Dropout(0.2))
        self.class_classifier.add_module('c_fc2', nn.Linear(1024, 512))
        self.class_classifier.add_module('c_bn2', nn.BatchNorm1d(512))
        self.class_classifier.add_module('c_relu2', nn.ReLU(True))
        self.class_classifier.add_module('c_fc3', nn.Linear(512, 2))
        self.class_classifier.add_module('c_softmax', nn.Softmax(dim = 1))

        self.domain_classifier = nn.Sequential()
        self.domain_classifier.add_module('d_fc1', nn.Linear(15 * 15 * 128 + 4*2*24, 1024))
        self.domain_classifier.add_module('d_bn1', nn.BatchNorm1d(1024))
        self.domain_classifier.add_module('d_relu1', nn.ReLU(True))
        self.domain_classifier.add_module('d_fc2', nn.Linear(1024, 2))
        self.domain_classifier.add_module('d_softmax', nn.Softmax(dim = 1))
    

    def forward(self, input_data, input_wave, alpha):
        feature1 = self.feature_image(input_data)
        feature2 = self.feature_wave(input_wave)
        feature1 = feature1.view(-1, 15 * 15 * 128)
        feature = torch.cat((feature1,feature2),1)
        reverse_feature = ReverseLayerF.apply(feature, alpha)
        print(feature.shape)
        class_output = self.class_classifier(feature)
        domain_output = self.domain_classifier(reverse_feature)
        return class_output, domain_output

# %%
model = CNNModel()
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 60733836

# %%
class Dataset(Dataset):
    def __init__(self, data_img,data_wave,info):
        #data loading
        self.x1 = data_img
        self.x2 = data_wave
        self.y = info
        self.n_samples = data_img.shape[0]


    def __getitem__(self,index):
        t1 = self.x1[index]
        t3 = self.x2[index]
        t2 = self.y[index]
        t1 = torch.tensor(t1)
        t1 = t1.permute((2,0,1))
        t2 = torch.tensor(t2)
        t3 = torch.tensor(t3)
        return (t1,t3,t2)
    
    def __len__(self):
        return self.n_samples
    
data = scipy.io.loadmat('/home/desktop/Desktop/22104412_Docs/EEG-COGMusic/Baseline/datasets/s08_datasets_Zscore_clipped.mat')

x_c=data['coh']
x_p = data['pli']
x_d = data['psd']
labels_skf = data['labels_kfold']
labels = data['valence']
de = data['EEGNet']

# %%
model
# Out:
# CNNModel(
#   (feature_image): Sequential(
#     (f_conv1): Conv2d(5, 32, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2))
#     (f_resblock1): ResidualBlock(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation1): ReLU()
#       (conv1): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation2): ReLU()
#       (conv2): Conv2d(32, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (f_resblock2): ResidualBlock(
#       (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation1): ReLU()
#       (conv1): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation2): ReLU()
#       (conv2): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (f_resblock3): ResidualBlock(
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation1): ReLU()
#       (conv1): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (activation2): ReLU()
#       (conv2): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     )
#     (f_adaptiveavgpool): AdaptiveAvgPool2d(output_size=(15, 15))
#   )
#   (feature_wave): Sequential(
#     (f_EEGNet): EEGNet(
#       (conv1): Conv2d(1, 16, kernel_size=(1, 32), stride=(1, 1))
#       (batchnorm1): BatchNorm2d(16, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#       (padding1): ZeroPad2d((16, 17, 0, 1))
#       (conv2): Conv2d(1, 4, kernel_size=(2, 32), stride=(1, 1))
#       (batchnorm2): BatchNorm2d(4, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#       (pooling2): MaxPool2d(kernel_size=2, stride=4, padding=0, dilation=1, ceil_mode=False)
#       (padding2): ZeroPad2d((2, 1, 4, 3))
#       (conv3): Conv2d(4, 4, kernel_size=(8, 4), stride=(1, 1))
#       (batchnorm3): BatchNorm2d(4, eps=False, momentum=0.1, affine=True, track_running_stats=True)
#       (pooling3): MaxPool2d(kernel_size=(2, 4), stride=(2, 4), padding=0, dilation=1, ceil_mode=False)
#     )
#   )
#   (class_classifier): Sequential(
#     (c_fc1): Linear(in_features=28992, out_features=1024, bias=True)
#     (c_bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (c_relu1): ReLU(inplace=True)
#     (c_drop1): Dropout(p=0.2, inplace=False)
#     (c_fc2): Linear(in_features=1024, out_features=512, bias=True)
#     (c_bn2): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (c_relu2): ReLU(inplace=True)
#     (c_fc3): Linear(in_features=512, out_features=2, bias=True)
#     (c_softmax): Softmax(dim=1)
#   )
#   (domain_classifier): Sequential(
#     (d_fc1): Linear(in_features=28992, out_features=1024, bias=True)
#     (d_bn1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (d_relu1): ReLU(inplace=True)
#     (d_fc2): Linear(in_features=1024, out_features=2, bias=True)
#     (d_softmax): Softmax(dim=1)
#   )
# )

# %%
x_n = np.zeros((40,75,32,32,5))
for trial in range(x_n.shape[0]):
    for sample in range(x_n.shape[1]):
        x_n[trial,sample,:,:,0] = x_c[trial,sample,:,:,0]+np.transpose(x_p[trial,sample,:,:,0])
        x_n[trial,sample,:,:,1] = x_c[trial,sample,:,:,1]+np.transpose(x_p[trial,sample,:,:,1])
        x_n[trial,sample,:,:,2] = x_c[trial,sample,:,:,2]+np.transpose(x_p[trial,sample,:,:,2])
        x_n[trial,sample,:,:,3] = x_c[trial,sample,:,:,3]+np.transpose(x_p[trial,sample,:,:,3])
        x_n[trial,sample,:,:,4] = x_c[trial,sample,:,:,4]+np.transpose(x_p[trial,sample,:,:,4])
    print(f'Completed trial {trial}')

for trial in range(x_n.shape[0]):
    for sample in range(x_n.shape[1]):
        for i in range(32):
            x_n[trial,sample,i,i,:] = x_d[trial,sample,i,:]
    print(f'Completed trial {trial}')
# Out:
# Completed trial 0
# Completed trial 1
# Completed trial 2
# Completed trial 3
# Completed trial 4
# Completed trial 5
# Completed trial 6
# Completed trial 7
# Completed trial 8
# Completed trial 9
# Completed trial 10
# Completed trial 11
# Completed trial 12
# Completed trial 13
# Completed trial 14
# Completed trial 15
# Completed trial 16
# Completed trial 17
# Completed trial 18
# Completed trial 19
# Completed trial 20
# Completed trial 21
# Completed trial 22
# Completed trial 23
# Completed trial 24
# Completed trial 25
# Completed trial 26
# Completed trial 27
# Completed trial 28
# Completed trial 29
# Completed trial 30
# Completed trial 31
# Completed trial 32
# Completed trial 33
# Completed trial 34
# Completed trial 35
# Completed trial 36
# Completed trial 37
# Completed trial 38
# Completed trial 39
# Completed trial 0
# Completed trial 1
# Completed trial 2
# Completed trial 3
# Completed trial 4
# Completed trial 5
# Completed trial 6
# Completed trial 7
# Completed trial 8
# Completed trial 9
# Completed trial 10
# Completed trial 11
# Completed trial 12
# Completed trial 13
# Completed trial 14
# Completed trial 15
# Completed trial 16
# Completed trial 17
# Completed trial 18
# Completed trial 19
# Completed trial 20
# Completed trial 21
# Completed trial 22
# Completed trial 23
# Completed trial 24
# Completed trial 25
# Completed trial 26
# Completed trial 27
# Completed trial 28
# Completed trial 29
# Completed trial 30
# Completed trial 31
# Completed trial 32
# Completed trial 33
# Completed trial 34
# Completed trial 35
# Completed trial 36
# Completed trial 37
# Completed trial 38
# Completed trial 39

# %%
v = labels_skf[:,0]
indices = np.where((v>5.5)|(v<4.5))[0]
indices.shape
# Out:
# (29,)

# %%
dt = x_n[indices]
labels = labels[indices]
trainLoss={}
valLoss = {}
trainAcc = {}
valAcc = {}

# %%
l_skf = np.zeros([40,1])
l_skf[np.where(labels_skf[:,0]>5)[0]] = 1
l_skf = l_skf[indices]

# %%
dt.shape,labels.shape,l_skf.shape,
# Out:
# ((29, 75, 32, 32, 5), (29, 75, 2), (29, 1))

# %%
de = de.transpose((0,1,3,2))
de = de[indices,:,np.newaxis,:,:]
de.shape
# Out:
# (29, 75, 1, 384, 32)

# %%
kf = skf(n_splits = 10)
log_pred_dict = {}
for k,(train_index,test_index) in enumerate(kf.split(dt, l_skf)):
    print(f'Fold {k+1} running')
    deTr,deV = np.concatenate(de[train_index],0), np.concatenate(de[test_index],0)
    dataTr, dataV = np.concatenate(dt[train_index],0), np.concatenate(dt[test_index],0)
    labelsTr, labelsV = np.concatenate(labels[train_index],0), np.concatenate(labels[test_index],0)
    tAV = []
    vAV = []
    y_train = np.argmax(labelsTr, axis=1)
    class_counts = np.bincount(y_train)
    num_classes = len(class_counts)
    total_samples = len(y_train)

    class_weights = []
    for count in class_counts:
        weight = 1 / (count / total_samples)
        class_weights.append(weight)
    
    weights_class = torch.tensor(np.array(class_weights))
    weights_class = weights_class.cuda()

    weights_domain = torch.tensor(np.array([1.05,5.5]))
    ## parameters
    bs = 100
    image_size = 32
    n_epoch = 50

    ## load data
    dataset_source = Dataset(dataTr, deTr, labelsTr)
    dataloader_source = DataLoader(dataset = dataset_source, batch_size = bs, shuffle = True)
 
    dataset_target = Dataset(dataV,deV, labelsV)
    dataloader_target = DataLoader(dataset = dataset_target, batch_size = 10, shuffle = True)
    
    testDS = Dataset(dataV,deV,labelsV)
    testDL = DataLoader(dataset = testDS, batch_size = bs)

    ###### model
    my_net = CNNModel()
     # Define your weights as a tensor
    optimizer = optim.SGD(my_net.parameters(), lr=0.0001, momentum= 0.9)
    loss_class = nn.CrossEntropyLoss(weight=weights_class)
    loss_domain = nn.CrossEntropyLoss(weight=weights_domain)

    cuda = True
    cudnn.benchmark = True

    if cuda:
        my_net = my_net.cuda()
        loss_class = loss_class.cuda()
        loss_domain = loss_domain.cuda()

    for p in my_net.parameters():
        p.requires_grad = True

    #### training    
    for epoch in range(n_epoch):

        len_dataloader = min(len(dataloader_source), len(dataloader_target))
        data_source_iter = iter(dataloader_source)
        data_target_iter = iter(dataloader_target)

        i = 0
        while i < len_dataloader:

            p = float(i + epoch * len_dataloader) / n_epoch / len_dataloader
            alpha = 2. / (1. + np.exp(-10 * p)) - 1

            # training model using source data
            data_source = next(data_source_iter)
            source_img, source_wave, source_label = data_source

            my_net.zero_grad()
            batch_size = len(source_label)

            domain_label = torch.zeros(batch_size,2)
            domain_label[:,0] = 1
            domain_label = domain_label.long()

            if cuda:
                source_img = source_img.cuda()
                source_wave = source_wave.cuda()
                source_label = source_label.cuda()
                domain_label = domain_label.cuda()

            class_output, domain_output = my_net(input_data=source_img.float(), input_wave = source_wave.float(), alpha=alpha)
            _, class_label = torch.max(source_label,dim=1)
            err_s_label = loss_class(class_output, source_label.float())
            err_s_domain = loss_domain(domain_output, domain_label.float())

            # training model using target data
            data_target = next(data_target_iter)
            target_img,target_wave, _ = data_target

            batch_size = len(target_img)

            domain_label = torch.zeros(batch_size,2)
            domain_label[:,1] = 1
            domain_label = domain_label.long()

            if cuda:
                target_img = target_img.cuda()
                target_wave = target_wave.cuda()
                domain_label = domain_label.cuda()

            _, domain_output = my_net(input_data=target_img.float(), input_wave = target_wave.float(), alpha=alpha)
            err_t_domain = loss_domain(domain_output, domain_label.float())
            err = err_t_domain + err_s_domain + err_s_label
            err.backward()
            optimizer.step()

            i += 1

            print ('epoch: %d, [iter: %d / all %d], err_s_label: %f, err_s_domain: %f, err_t_domain: %f' \
                % (epoch, i, len_dataloader, err_s_label.cpu().data.numpy(),
                    err_s_domain.cpu().data.numpy(), err_t_domain.cpu().data.numpy()))

        tAV.append(test(dataloader_source, epoch, my_net, 'source'))
        vAV.append(test(dataloader_target, epoch, my_net, 'target'))
    trainAcc[str(k)] = tAV
    valAcc[str(k)] = vAV
    print(f'Fold {k} Completed')
# Out:
# Fold 1 running
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 1 / all 20], err_s_label: 1.366622, err_s_domain: 0.735890, err_t_domain: 3.941936
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 2 / all 20], err_s_label: 1.404003, err_s_domain: 0.739976, err_t_domain: 3.790384
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 3 / all 20], err_s_label: 1.389585, err_s_domain: 0.759002, err_t_domain: 3.684385
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 4 / all 20], err_s_label: 1.402417, err_s_domain: 0.786101, err_t_domain: 3.556102
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 5 / all 20], err_s_label: 1.376137, err_s_domain: 0.818004, err_t_domain: 3.378201
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 6 / all 20], err_s_label: 1.378894, err_s_domain: 0.852640, err_t_domain: 3.289988
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 7 / all 20], err_s_label: 1.375702, err_s_domain: 0.900181, err_t_domain: 3.046998
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 8 / all 20], err_s_label: 1.412130, err_s_domain: 0.944847, err_t_domain: 2.910238
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 9 / all 20], err_s_label: 1.393796, err_s_domain: 0.993579, err_t_domain: 2.719808
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 10 / all 20], err_s_label: 1.363140, err_s_domain: 1.033104, err_t_domain: 2.609923
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 11 / all 20], err_s_label: 1.365285, err_s_domain: 1.068933, err_t_domain: 2.508319
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 12 / all 20], err_s_label: 1.293148, err_s_domain: 1.107797, err_t_domain: 2.312241
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 13 / all 20], err_s_label: 1.309662, err_s_domain: 1.137819, err_t_domain: 2.254140
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 14 / all 20], err_s_label: 1.334798, err_s_domain: 1.157315, err_t_domain: 2.295725
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 15 / all 20], err_s_label: 1.346216, err_s_domain: 1.183807, err_t_domain: 2.151242
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 16 / all 20], err_s_label: 1.348855, err_s_domain: 1.196561, err_t_domain: 2.080965
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 17 / all 20], err_s_label: 1.330274, err_s_domain: 1.222512, err_t_domain: 2.026492
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 18 / all 20], err_s_label: 1.306015, err_s_domain: 1.241924, err_t_domain: 2.003644
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 19 / all 20], err_s_label: 1.320686, err_s_domain: 1.251304, err_t_domain: 1.936013
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 0, [iter: 20 / all 20], err_s_label: 1.249566, err_s_domain: 1.269995, err_t_domain: 1.930559
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 0 for source dataset is 62.97435897435897
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 0 for target dataset is 58.666666666666664
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 1 / all 20], err_s_label: 1.311200, err_s_domain: 1.150527, err_t_domain: 2.242164
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 2 / all 20], err_s_label: 1.343509, err_s_domain: 1.313179, err_t_domain: 1.859672
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 3 / all 20], err_s_label: 1.294233, err_s_domain: 1.365420, err_t_domain: 1.748297
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 4 / all 20], err_s_label: 1.306630, err_s_domain: 1.375694, err_t_domain: 1.727367
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 5 / all 20], err_s_label: 1.283944, err_s_domain: 1.377984, err_t_domain: 1.725013
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 6 / all 20], err_s_label: 1.268563, err_s_domain: 1.378680, err_t_domain: 1.724121
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 7 / all 20], err_s_label: 1.318741, err_s_domain: 1.378818, err_t_domain: 1.723000
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 8 / all 20], err_s_label: 1.218252, err_s_domain: 1.378858, err_t_domain: 1.723066
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 9 / all 20], err_s_label: 1.296215, err_s_domain: 1.378897, err_t_domain: 1.722961
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 10 / all 20], err_s_label: 1.278890, err_s_domain: 1.378908, err_t_domain: 1.722954
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 11 / all 20], err_s_label: 1.225177, err_s_domain: 1.378919, err_t_domain: 1.722967
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 12 / all 20], err_s_label: 1.321285, err_s_domain: 1.378917, err_t_domain: 1.722945
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 13 / all 20], err_s_label: 1.304258, err_s_domain: 1.378921, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 14 / all 20], err_s_label: 1.310064, err_s_domain: 1.378923, err_t_domain: 1.722947
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 15 / all 20], err_s_label: 1.248324, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 16 / all 20], err_s_label: 1.315376, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 17 / all 20], err_s_label: 1.191854, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 18 / all 20], err_s_label: 1.294731, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 19 / all 20], err_s_label: 1.242241, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 1, [iter: 20 / all 20], err_s_label: 1.250354, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 1 for source dataset is 60.30769230769231
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 1 for target dataset is 64.88888888888889
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 1 / all 20], err_s_label: 1.395278, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 2 / all 20], err_s_label: 1.276506, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 3 / all 20], err_s_label: 1.224007, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 4 / all 20], err_s_label: 1.197084, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 5 / all 20], err_s_label: 1.363189, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 6 / all 20], err_s_label: 1.220671, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 7 / all 20], err_s_label: 1.291286, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 8 / all 20], err_s_label: 1.326211, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 9 / all 20], err_s_label: 1.286893, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 10 / all 20], err_s_label: 1.302488, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 11 / all 20], err_s_label: 1.262141, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 12 / all 20], err_s_label: 1.315980, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 13 / all 20], err_s_label: 1.170107, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 14 / all 20], err_s_label: 1.256644, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 15 / all 20], err_s_label: 1.210651, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 16 / all 20], err_s_label: 1.202115, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 17 / all 20], err_s_label: 1.167406, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 18 / all 20], err_s_label: 1.242421, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 19 / all 20], err_s_label: 1.259024, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 2, [iter: 20 / all 20], err_s_label: 1.322543, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 2 for source dataset is 67.28205128205128
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 2 for target dataset is 53.333333333333336
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 1 / all 20], err_s_label: 1.210541, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 2 / all 20], err_s_label: 1.223569, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 3 / all 20], err_s_label: 1.188019, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 4 / all 20], err_s_label: 1.197896, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 5 / all 20], err_s_label: 1.070204, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 6 / all 20], err_s_label: 1.110405, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 7 / all 20], err_s_label: 1.255128, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 8 / all 20], err_s_label: 1.234639, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 9 / all 20], err_s_label: 1.186583, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 10 / all 20], err_s_label: 1.175850, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 11 / all 20], err_s_label: 1.248819, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 12 / all 20], err_s_label: 1.208254, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 13 / all 20], err_s_label: 1.166511, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 14 / all 20], err_s_label: 1.181223, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 15 / all 20], err_s_label: 1.252433, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 16 / all 20], err_s_label: 1.223574, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 17 / all 20], err_s_label: 1.186288, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 18 / all 20], err_s_label: 1.232155, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 19 / all 20], err_s_label: 1.219622, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 3, [iter: 20 / all 20], err_s_label: 1.285316, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 3 for source dataset is 57.38461538461539
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 3 for target dataset is 66.66666666666667
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 1 / all 20], err_s_label: 1.245753, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 2 / all 20], err_s_label: 1.200200, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 3 / all 20], err_s_label: 1.185291, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 4 / all 20], err_s_label: 1.145786, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 5 / all 20], err_s_label: 1.350326, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 6 / all 20], err_s_label: 1.287975, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 7 / all 20], err_s_label: 1.250755, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 8 / all 20], err_s_label: 1.339101, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 9 / all 20], err_s_label: 1.356795, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 10 / all 20], err_s_label: 1.213995, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 11 / all 20], err_s_label: 1.210159, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 12 / all 20], err_s_label: 1.373128, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 13 / all 20], err_s_label: 1.437141, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 14 / all 20], err_s_label: 1.423787, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 15 / all 20], err_s_label: 1.240437, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 16 / all 20], err_s_label: 1.283602, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 17 / all 20], err_s_label: 1.253129, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 18 / all 20], err_s_label: 1.346292, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 19 / all 20], err_s_label: 1.304008, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 4, [iter: 20 / all 20], err_s_label: 1.383686, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 4 for source dataset is 71.33333333333333
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 4 for target dataset is 69.77777777777777
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 1 / all 20], err_s_label: 1.145148, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 2 / all 20], err_s_label: 1.194165, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 3 / all 20], err_s_label: 1.401501, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 4 / all 20], err_s_label: 1.293238, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 5 / all 20], err_s_label: 1.371090, err_s_domain: 1.378925, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 6 / all 20], err_s_label: 1.182909, err_s_domain: 1.378925, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 7 / all 20], err_s_label: 1.331605, err_s_domain: 1.378925, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 8 / all 20], err_s_label: 1.372667, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 9 / all 20], err_s_label: 1.270169, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 10 / all 20], err_s_label: 1.480733, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 11 / all 20], err_s_label: 1.272544, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 12 / all 20], err_s_label: 1.181718, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 13 / all 20], err_s_label: 1.201801, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 14 / all 20], err_s_label: 1.244865, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 15 / all 20], err_s_label: 1.223422, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 16 / all 20], err_s_label: 1.257309, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 17 / all 20], err_s_label: 1.193297, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 18 / all 20], err_s_label: 1.192548, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 19 / all 20], err_s_label: 1.147566, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 5, [iter: 20 / all 20], err_s_label: 1.220337, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 5 for source dataset is 61.38461538461539
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 5 for target dataset is 66.22222222222223
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 1 / all 20], err_s_label: 1.320836, err_s_domain: 1.378925, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 2 / all 20], err_s_label: 1.305791, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 3 / all 20], err_s_label: 1.496498, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 4 / all 20], err_s_label: 1.267774, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 5 / all 20], err_s_label: 1.125459, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 6 / all 20], err_s_label: 1.230758, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 7 / all 20], err_s_label: 1.168521, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 8 / all 20], err_s_label: 1.335971, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 9 / all 20], err_s_label: 1.141458, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 10 / all 20], err_s_label: 1.163511, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 11 / all 20], err_s_label: 1.192012, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 12 / all 20], err_s_label: 1.218208, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 13 / all 20], err_s_label: 1.144864, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 14 / all 20], err_s_label: 1.210525, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 15 / all 20], err_s_label: 1.201212, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 16 / all 20], err_s_label: 1.173372, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 17 / all 20], err_s_label: 1.098783, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 18 / all 20], err_s_label: 1.195850, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 19 / all 20], err_s_label: 1.147385, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 6, [iter: 20 / all 20], err_s_label: 1.213498, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 6 for source dataset is 73.28205128205128
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 6 for target dataset is 60.888888888888886
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 1 / all 20], err_s_label: 1.190317, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 2 / all 20], err_s_label: 1.132646, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 3 / all 20], err_s_label: 1.205071, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 4 / all 20], err_s_label: 1.150558, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 5 / all 20], err_s_label: 1.187519, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 6 / all 20], err_s_label: 1.146588, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 7 / all 20], err_s_label: 1.089076, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 8 / all 20], err_s_label: 1.163482, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 9 / all 20], err_s_label: 1.103606, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 10 / all 20], err_s_label: 1.165852, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 11 / all 20], err_s_label: 1.088322, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 12 / all 20], err_s_label: 1.170617, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 13 / all 20], err_s_label: 1.140365, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 14 / all 20], err_s_label: 1.121203, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 15 / all 20], err_s_label: 1.210894, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 16 / all 20], err_s_label: 1.136883, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 17 / all 20], err_s_label: 1.153564, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 18 / all 20], err_s_label: 1.190171, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 19 / all 20], err_s_label: 1.186500, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 7, [iter: 20 / all 20], err_s_label: 1.275147, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 7 for source dataset is 72.56410256410257
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 7 for target dataset is 57.333333333333336
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 1 / all 20], err_s_label: 1.116229, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 2 / all 20], err_s_label: 1.027816, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 3 / all 20], err_s_label: 1.146830, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 4 / all 20], err_s_label: 1.134044, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 5 / all 20], err_s_label: 1.203194, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 6 / all 20], err_s_label: 1.057478, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 7 / all 20], err_s_label: 1.044466, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 8 / all 20], err_s_label: 1.099559, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 9 / all 20], err_s_label: 1.102135, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 10 / all 20], err_s_label: 1.070063, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 11 / all 20], err_s_label: 1.077597, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 12 / all 20], err_s_label: 1.160174, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 13 / all 20], err_s_label: 1.138565, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 14 / all 20], err_s_label: 1.151601, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 15 / all 20], err_s_label: 1.148453, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 16 / all 20], err_s_label: 1.159026, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 17 / all 20], err_s_label: 1.091624, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 18 / all 20], err_s_label: 1.062060, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 19 / all 20], err_s_label: 1.151987, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 8, [iter: 20 / all 20], err_s_label: 1.178333, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 8 for source dataset is 77.17948717948718
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 8 for target dataset is 68.44444444444444
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 1 / all 20], err_s_label: 1.114197, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 2 / all 20], err_s_label: 1.117352, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 3 / all 20], err_s_label: 1.131979, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 4 / all 20], err_s_label: 1.063893, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 5 / all 20], err_s_label: 1.097743, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 6 / all 20], err_s_label: 1.116055, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 7 / all 20], err_s_label: 1.053347, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 8 / all 20], err_s_label: 1.119463, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 9 / all 20], err_s_label: 1.058210, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 10 / all 20], err_s_label: 1.090750, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 11 / all 20], err_s_label: 1.035989, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 12 / all 20], err_s_label: 1.009383, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 13 / all 20], err_s_label: 1.046639, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 14 / all 20], err_s_label: 1.166041, err_s_domain: 1.378925, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 15 / all 20], err_s_label: 1.043517, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 16 / all 20], err_s_label: 1.119688, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 17 / all 20], err_s_label: 1.061114, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 18 / all 20], err_s_label: 1.128012, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 19 / all 20], err_s_label: 1.152725, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 9, [iter: 20 / all 20], err_s_label: 1.070231, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 9 for source dataset is 79.07692307692308
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 9 for target dataset is 70.66666666666667
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 1 / all 20], err_s_label: 1.050465, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 2 / all 20], err_s_label: 1.081078, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 3 / all 20], err_s_label: 1.086931, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 4 / all 20], err_s_label: 1.081310, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 5 / all 20], err_s_label: 0.965218, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 6 / all 20], err_s_label: 1.007800, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 7 / all 20], err_s_label: 1.099205, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 8 / all 20], err_s_label: 1.003055, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 9 / all 20], err_s_label: 1.106491, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 10 / all 20], err_s_label: 1.070245, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 11 / all 20], err_s_label: 1.102848, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 12 / all 20], err_s_label: 1.076961, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 13 / all 20], err_s_label: 1.102833, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 14 / all 20], err_s_label: 1.235889, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 15 / all 20], err_s_label: 1.069445, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 16 / all 20], err_s_label: 1.090785, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 17 / all 20], err_s_label: 1.076465, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 18 / all 20], err_s_label: 1.180344, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 19 / all 20], err_s_label: 1.090803, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([50, 28992])
# torch.Size([10, 28992])
# epoch: 10, [iter: 20 / all 20], err_s_label: 1.002096, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([50, 28992])
# Epoch 10 for source dataset is 76.87179487179488
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([5, 28992])
# Epoch 10 for target dataset is 60.888888888888886
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 1 / all 20], err_s_label: 1.047363, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 2 / all 20], err_s_label: 1.044123, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 3 / all 20], err_s_label: 1.189741, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 4 / all 20], err_s_label: 1.229229, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 5 / all 20], err_s_label: 1.200952, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 6 / all 20], err_s_label: 1.079876, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 7 / all 20], err_s_label: 1.087874, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 8 / all 20], err_s_label: 1.085557, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 9 / all 20], err_s_label: 1.159031, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 10 / all 20], err_s_label: 0.986362, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 11 / all 20], err_s_label: 1.023435, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 12 / all 20], err_s_label: 1.091497, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 13 / all 20], err_s_label: 1.116478, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 14 / all 20], err_s_label: 1.117193, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 15 / all 20], err_s_label: 1.133438, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 11, [iter: 16 / all 20], err_s_label: 1.000130, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# ...
# torch.Size([10, 28992])
# epoch: 45, [iter: 2 / all 15], err_s_label: 0.917757, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 3 / all 15], err_s_label: 0.895841, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 4 / all 15], err_s_label: 0.849697, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 5 / all 15], err_s_label: 0.919570, err_s_domain: 1.378924, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 6 / all 15], err_s_label: 0.926580, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 7 / all 15], err_s_label: 0.864045, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 8 / all 15], err_s_label: 0.995097, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 9 / all 15], err_s_label: 0.839357, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 10 / all 15], err_s_label: 0.878159, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 11 / all 15], err_s_label: 1.058080, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 12 / all 15], err_s_label: 0.818862, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 13 / all 15], err_s_label: 0.975575, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 14 / all 15], err_s_label: 0.943746, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 45, [iter: 15 / all 15], err_s_label: 0.881524, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([25, 28992])
# Epoch 45 for source dataset is 88.14814814814815
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# Epoch 45 for target dataset is 53.333333333333336
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 1 / all 15], err_s_label: 0.904326, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 2 / all 15], err_s_label: 0.903552, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 3 / all 15], err_s_label: 0.841600, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 4 / all 15], err_s_label: 0.891046, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 5 / all 15], err_s_label: 0.895895, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 6 / all 15], err_s_label: 0.827302, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 7 / all 15], err_s_label: 0.868444, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 8 / all 15], err_s_label: 0.839090, err_s_domain: 1.378922, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 9 / all 15], err_s_label: 0.855330, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 10 / all 15], err_s_label: 0.796303, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 11 / all 15], err_s_label: 0.899184, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 12 / all 15], err_s_label: 0.800836, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 13 / all 15], err_s_label: 0.886481, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 14 / all 15], err_s_label: 0.833359, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 46, [iter: 15 / all 15], err_s_label: 0.889601, err_s_domain: 1.378923, err_t_domain: 1.722946
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([25, 28992])
# Epoch 46 for source dataset is 91.80246913580247
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# Epoch 46 for target dataset is 52.0
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 1 / all 15], err_s_label: 0.858617, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 2 / all 15], err_s_label: 0.906512, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 3 / all 15], err_s_label: 0.864970, err_s_domain: 1.378924, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 4 / all 15], err_s_label: 0.880949, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 5 / all 15], err_s_label: 0.810364, err_s_domain: 1.378924, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 6 / all 15], err_s_label: 0.838748, err_s_domain: 1.378924, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 7 / all 15], err_s_label: 0.904440, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 8 / all 15], err_s_label: 0.778517, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 9 / all 15], err_s_label: 0.907336, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 10 / all 15], err_s_label: 0.844621, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 11 / all 15], err_s_label: 0.903474, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 12 / all 15], err_s_label: 0.912473, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 13 / all 15], err_s_label: 0.966475, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 14 / all 15], err_s_label: 0.877863, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 47, [iter: 15 / all 15], err_s_label: 0.954439, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([25, 28992])
# Epoch 47 for source dataset is 85.4320987654321
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# Epoch 47 for target dataset is 54.0
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 1 / all 15], err_s_label: 0.828639, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 2 / all 15], err_s_label: 0.814658, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 3 / all 15], err_s_label: 0.907557, err_s_domain: 1.378922, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 4 / all 15], err_s_label: 0.912494, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 5 / all 15], err_s_label: 0.895567, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 6 / all 15], err_s_label: 1.022145, err_s_domain: 1.378924, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 7 / all 15], err_s_label: 0.934532, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 8 / all 15], err_s_label: 0.844509, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 9 / all 15], err_s_label: 0.968392, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 10 / all 15], err_s_label: 0.868561, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 11 / all 15], err_s_label: 0.851765, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 12 / all 15], err_s_label: 0.886358, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 13 / all 15], err_s_label: 0.951400, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 14 / all 15], err_s_label: 0.832178, err_s_domain: 1.378922, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 48, [iter: 15 / all 15], err_s_label: 0.921753, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([25, 28992])
# Epoch 48 for source dataset is 90.5679012345679
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# Epoch 48 for target dataset is 50.0
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 1 / all 15], err_s_label: 0.855323, err_s_domain: 1.378923, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 2 / all 15], err_s_label: 0.871180, err_s_domain: 1.378923, err_t_domain: 1.722942
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 3 / all 15], err_s_label: 0.947965, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 4 / all 15], err_s_label: 0.915955, err_s_domain: 1.378923, err_t_domain: 1.722945
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 5 / all 15], err_s_label: 0.802074, err_s_domain: 1.378922, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 6 / all 15], err_s_label: 0.868199, err_s_domain: 1.378922, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 7 / all 15], err_s_label: 0.844605, err_s_domain: 1.378923, err_t_domain: 1.722944
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 8 / all 15], err_s_label: 0.837906, err_s_domain: 1.378922, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 9 / all 15], err_s_label: 0.941398, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 10 / all 15], err_s_label: 0.939219, err_s_domain: 1.378922, err_t_domain: 1.722940
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 11 / all 15], err_s_label: 0.804784, err_s_domain: 1.378923, err_t_domain: 1.722947
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 12 / all 15], err_s_label: 0.855180, err_s_domain: 1.378923, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 13 / all 15], err_s_label: 0.840211, err_s_domain: 1.378922, err_t_domain: 1.722943
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 14 / all 15], err_s_label: 0.843258, err_s_domain: 1.378923, err_t_domain: 1.722941
# torch.Size([100, 28992])
# torch.Size([10, 28992])
# epoch: 49, [iter: 15 / all 15], err_s_label: 0.947403, err_s_domain: 1.378922, err_t_domain: 1.722945
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([100, 28992])
# torch.Size([25, 28992])
# Epoch 49 for source dataset is 91.11111111111111
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# torch.Size([10, 28992])
# Epoch 49 for target dataset is 54.0
# Fold 9 Completed

# %%
target_img.float()
# Out:
# tensor([[[[2.2779e+00, 5.9574e-01, 3.5781e-01,  ..., 3.5448e-01,
#            4.3071e-01, 6.3914e-01],
#           [7.8125e-02, 5.7037e+00, 8.8726e-01,  ..., 1.9957e-01,
#            9.4475e-01, 9.5497e-01],
#           [3.1250e-02, 3.6458e-02, 4.6568e+00,  ..., 1.1359e-01,
#            9.6055e-01, 8.1226e-01],
#           ...,
#           [1.5625e-02, 9.3750e-02, 1.0417e-01,  ..., 5.2649e+00,
#            1.4409e-01, 1.8527e-01],
#           [6.7708e-02, 3.1250e-02, 2.0833e-02,  ..., 3.1250e-02,
#            5.4653e+00, 8.8539e-01],
#           [1.5625e-01, 5.2083e-03, 1.5625e-02,  ..., 1.5625e-02,
#            3.1250e-02, 6.3023e+00]],
#
#          [[1.9474e+00, 7.5450e-01, 6.8079e-01,  ..., 2.0397e-01,
#            6.8857e-01, 6.4750e-01],
#           [9.3750e-02, 2.1922e+00, 8.8815e-01,  ..., 1.0430e-01,
#            9.1100e-01, 8.9847e-01],
#           [6.6667e-01, 7.1875e-01, 2.3238e+00,  ..., 1.4875e-01,
#            8.6037e-01, 7.3858e-01],
#           ...,
#           [2.8646e-01, 3.9583e-01, 2.5521e-01,  ..., 1.1310e+00,
#            1.2003e-01, 7.4854e-02],
#           [5.2083e-02, 0.0000e+00, 1.3542e-01,  ..., 4.9479e-01,
#            1.8730e+00, 8.5278e-01],
#           [9.8958e-02, 3.6458e-02, 1.7188e-01,  ..., 5.2604e-01,
#            1.0417e-02, 1.8403e+00]],
#
#          [[1.0905e+00, 4.8742e-01, 4.9341e-01,  ..., 3.4743e-01,
#            4.1772e-01, 4.3869e-01],
#           [2.0312e-01, 5.2238e-01, 7.4729e-01,  ..., 4.4386e-01,
#            6.3660e-01, 4.6532e-01],
#           ...,
#           [1.4062e-01, 2.3958e-01, 2.2917e-01,  ..., 1.5741e+00,
#            6.9646e-01, 7.1600e-01],
#           [2.9688e-01, 1.9792e-01, 2.0833e-01,  ..., 3.5417e-01,
#            2.1272e+00, 8.1407e-01],
#           [3.2292e-01, 2.2396e-01, 1.7708e-01,  ..., 5.2083e-03,
#            8.8542e-02, 2.5453e+00]],
#
#          [[1.3548e+00, 6.2389e-01, 4.7078e-01,  ..., 2.8936e-01,
#            4.2780e-01, 4.1403e-01],
#           [3.6979e-01, 7.7282e-01, 4.6395e-01,  ..., 3.1225e-01,
#            6.8766e-01, 6.4529e-01],
#           [2.5521e-01, 5.4688e-01, 8.9203e-01,  ..., 2.8985e-01,
#            5.2362e-01, 3.1124e-01],
#           ...,
#           [3.3333e-01, 3.4896e-01, 2.8125e-01,  ..., 5.5376e-01,
#            2.2011e-01, 3.0936e-01],
#           [1.0417e-02, 9.8958e-02, 1.8750e-01,  ..., 2.2396e-01,
#            6.9112e-01, 7.5122e-01],
#           [1.5104e-01, 1.6667e-01, 1.0938e-01,  ..., 1.0938e-01,
#            5.2083e-03, 6.1688e-01]],
#
#          [[4.4996e-01, 3.7585e-01, 2.7522e-01,  ..., 2.6238e-01,
#            2.0944e-01, 1.9267e-01],
#           [1.4062e-01, 4.6449e-01, 5.3215e-01,  ..., 3.0975e-01,
#            5.3230e-01, 5.0392e-01],
#           [2.2396e-01, 1.0417e-02, 6.0129e-01,  ..., 3.6356e-01,
#            5.9092e-01, 5.9914e-01],
#           ...,
#           [1.5625e-02, 8.3333e-02, 1.0417e-02,  ..., 1.3059e-01,
#            3.5208e-01, 1.9573e-01],
#           [1.5625e-02, 2.0833e-02, 2.6042e-02,  ..., 1.5625e-02,
#            6.9250e-01, 7.6809e-01],
#           [6.7708e-02, 6.7708e-02, 7.2917e-02,  ..., 3.1250e-02,
#            6.7708e-02, 2.1718e-01]],
#
#          [[3.9349e-01, 2.5280e-01, 1.9222e-01,  ..., 2.8202e-01,
#            2.5743e-01, 2.8140e-01],
#           [1.9792e-01, 2.8928e-01, 6.6094e-01,  ..., 2.6559e-01,
#            7.3229e-01, 7.2407e-01],
#           [1.5625e-02, 6.2500e-02, 4.1456e-01,  ..., 4.8080e-01,
#            7.6099e-01, 5.5305e-01],
#           ...,
#           [7.8125e-02, 2.0833e-02, 1.0417e-02,  ..., 1.2738e-01,
#            3.6519e-01, 2.5836e-01],
#           [4.1667e-02, 2.6042e-02, 1.0417e-01,  ..., 1.2500e-01,
#            7.0842e-01, 8.5666e-01],
#           [1.4583e-01, 8.8542e-02, 1.0417e-02,  ..., 8.3333e-02,
#            4.6875e-02, 2.0812e-01]]]], device='cuda:0')

# %%
class_output.shape
# Out:
# torch.Size([100, 2])

# %%
vAV = np.array(list(valAcc.values()))

# %%
VA = np.max(vAV,1)
print(VA)
# Out:
# [74.22222222 70.66666667 81.33333333 85.33333333 63.55555556 60.88888889
#  52.         60.88888889 46.22222222 56.        ]

# %%
np.mean(VA)
# Out:
# 65.11111111111111
